# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data=pd.read_csv("../Data/Datos_Transformados.csv")

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31211 entries, 0 to 31210
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          31211 non-null  object
#  1   Source           31211 non-null  object
#  2   Destination      31211 non-null  object
#  3   Duration         31211 non-null  int64
#  4   Total stops      31211 non-null  int64
#  5   Market           31211 non-null  object
#  6   Date             31211 non-null  object
#  7   Departure_Day    31211 non-null  int64
#  8   Departure_Month  31211 non-null  int64
#  9   Departure_Year   31211 non-null  int64
#  10  Price            31211 non-null  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 2.6+ MB

# %%
print("se cuenta con un total de ",Data['Airline'].nunique()," Aerolineas")
# Out:
# se cuenta con un total de  20  Aerolineas

# %%
datos_rutas=Data.groupby(['Market'])['Date'].count().reset_index()
print(datos_rutas[['Market','Date']])
# Graficar barras
plt.bar(datos_rutas['Market'], datos_rutas['Date'])

# Configurar etiquetas y título
plt.xlabel('Rutas')
plt.ylabel('Cantidad de datos')
plt.title('rutas vs count')
# Rotar los nombres de las categorías en posición vertical
plt.xticks(rotation='vertical')
# Mostrar la gráfica
plt.show()
# Out:
#      Market  Date
# 0   NYC-PAR  3332
# 1   NYC-RUH  1608
# 2   NYC-SVO  1160
# 3   PAR-NYC  9656
# 4   PAR-RUH  3735
# 5   PAR-SVO  1252
# 6   RUH-NYC  3218
# 7   RUH-PAR   398
# 8   RUH-SVO   760
# 9   SVO-NYC  3246
# 10  SVO-PAR  1865
# 11  SVO-RUH   981

# %% [markdown]
# el grafica de barras nos da un vista de como esta distribuida la informacion y de los datos por ruta.

# %% [markdown]
# Analisis de Market vs Price

# %%
sns.catplot(y = "Price", x = "Market", data = Data.sort_values("Price", ascending = False), kind="boxen", height = 6, aspect = 3)
plt.show()

# %% [markdown]
# Analisis de Source vs Price

# %%
sns.catplot(y = "Price", x = "Source", data = Data.sort_values("Price", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %% [markdown]
# Analisi de Destination vs Price

# %%
sns.catplot(y = "Price", x = "Destination", data = Data.sort_values("Price", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()
